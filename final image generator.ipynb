# %%
# importing libraries
#here

! pip install torch diffusers matplotlib transformers accelerate
# !pip install Pillow
# !pip install torch
# !pip install diffusers
# !pip install customtkinter
# !pip install tkinter
# !pip install torch diffusers matplotlib transformers accelerate
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
# ...

# %%
# Import Dependencies
# importing libraires here in this part
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt

# %%
# using here hugging face pre trained model api
#stable diffusion model use (open source)

authorization_token = "use here hugging face api by creating hugging face account not able to paste as gihub policy"
# model selection repo in hugging face
modelid = #just remove the comment from here and selsect this model"CompVis/stable-diffusion-v1-4"
device = # it a device"cuda"

# %%
# leading the model with help of the stable diffusion pipeline using hugginface repo
##pipe = StableDiffusionPipeline.from_pretrained(modelid, revision="fp16", torch_dtype=torch.float16, use_auth_token=authorization_token)
#remove the commmnet form thsi to run 
pipe.to(device)
# Out:
# Keyword arguments {'use_auth_token': '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'} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/2880f2ca379f41b0226444936bb7a6766a227587/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/2880f2ca379f41b0226444936bb7a6766a227587/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# ...

# %%
with autocast(device):
  textprompt = str(input("Enter your promt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
